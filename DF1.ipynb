# %% [markdown]
# ## DF1

# %%
import pandas as pd

# %%
df1 = pd.read_csv('//Users//B//Documents//GIT//Data-analysis-with-Pandas//CODES//pandas//nba.csv')

# %%
df1.head(5)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
df1.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
df1.shape
# Out:
# (458, 9)

# %%
df1.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
df1.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df1.axes
#bundles index and columns
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df1.get_dtype_counts()
# Out:
# float64    4
# object     5
# dtype: int64

# %%
rev = pd.read_csv("//Users//B//Documents//GIT//Data-analysis-with-Pandas//CODES//pandas//revenue.csv", index_col = 'Date')

# %%
s = pd.Series([1,2,3])

# %%
s.sum()
# Out:
# 6

# %%
print("sum of columns") 
rev.sum(axis = 'rows') #or 'index'
#sums vertical axes = 0
# Out:
# sum of columns
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
#or
rev.sum() #all of the values from the column
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
print("sum of rows") 
rev.sum(axis = 1) #all of the values from the column
# or axis = 'columns'
# Out:
# sum of rows
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %% [markdown]
# ## select a single column from DF

# %%
df1.Name
#returns a series
#df1.Number
#only works when columns dont have spaces

Output = None #hides outout of cell

# %%
#works when columns have spaces
df1["Name"]
# Out:
# 0                Avery Bradley
# 1                  Jae Crowder
# 2                 John Holland
# 3                  R.J. Hunter
# 4                Jonas Jerebko
# 5                 Amir Johnson
# 6                Jordan Mickey
# 7                 Kelly Olynyk
# 8                 Terry Rozier
# 9                 Marcus Smart
# 10             Jared Sullinger
# 11               Isaiah Thomas
# 12                 Evan Turner
# 13                 James Young
# 14                Tyler Zeller
# 15            Bojan Bogdanovic
# 16                Markel Brown
# 17             Wayne Ellington
# 18     Rondae Hollis-Jefferson
# 19                Jarrett Jack
# 20              Sergey Karasev
# 21             Sean Kilpatrick
# 22                Shane Larkin
# 23                 Brook Lopez
# 24            Chris McCullough
# 25                 Willie Reed
# 26             Thomas Robinson
# 27                  Henry Sims
# 28                Donald Sloan
# 29              Thaddeus Young
# ...

# %%
type(df1["Name"])
#single column selections treats it as a series, which can be chained in sequence
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Select multiple columns in a DF

# %%
#selected multiple values in a list
df1[["Name","Team"]]
#returns as a DF
# Out:
#                         Name                    Team
# 0              Avery Bradley          Boston Celtics
# 1                Jae Crowder          Boston Celtics
# 2               John Holland          Boston Celtics
# 3                R.J. Hunter          Boston Celtics
# 4              Jonas Jerebko          Boston Celtics
# 5               Amir Johnson          Boston Celtics
# 6              Jordan Mickey          Boston Celtics
# 7               Kelly Olynyk          Boston Celtics
# 8               Terry Rozier          Boston Celtics
# 9               Marcus Smart          Boston Celtics
# 10           Jared Sullinger          Boston Celtics
# 11             Isaiah Thomas          Boston Celtics
# 12               Evan Turner          Boston Celtics
# 13               James Young          Boston Celtics
# 14              Tyler Zeller          Boston Celtics
# 15          Bojan Bogdanovic           Brooklyn Nets
# 16              Markel Brown           Brooklyn Nets
# ...

# %%
df1[["Name","Number","College","Salary"]].tail(5)
# Out:
#              Name  Number College     Salary
# 453  Shelvin Mack     8.0  Butler  2433333.0
# 454     Raul Neto    25.0     NaN   900000.0
# 455  Tibor Pleiss    21.0     NaN  2900000.0
# 456   Jeff Withey    24.0  Kansas   947276.0
# 457           NaN     NaN     NaN        NaN

# %%
#variabalize
select = ["Name","College","Salary"]
df1[select]
# Out:
#                         Name            College      Salary
# 0              Avery Bradley              Texas   7730337.0
# 1                Jae Crowder          Marquette   6796117.0
# 2               John Holland  Boston University         NaN
# 3                R.J. Hunter      Georgia State   1148640.0
# 4              Jonas Jerebko                NaN   5000000.0
# 5               Amir Johnson                NaN  12000000.0
# 6              Jordan Mickey                LSU   1170960.0
# 7               Kelly Olynyk            Gonzaga   2165160.0
# 8               Terry Rozier         Louisville   1824360.0
# 9               Marcus Smart     Oklahoma State   3431040.0
# 10           Jared Sullinger         Ohio State   2569260.0
# 11             Isaiah Thomas         Washington   6912869.0
# 12               Evan Turner         Ohio State   3425510.0
# 13               James Young           Kentucky   1749840.0
# 14              Tyler Zeller     North Carolina   2616975.0
# ...

# %% [markdown]
# ## Add new column to DF

# %%
#option 1
df1["League"] = 'NBA'

# %%
df1
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
df1.insert(2, column= 'Sport', value = 'BBall')

# %%
df1
# Out:
#                         Name                    Team  Sport  Number Position  \
# 0              Avery Bradley          Boston Celtics  BBall     0.0       PG
# 1                Jae Crowder          Boston Celtics  BBall    99.0       SF
# 2               John Holland          Boston Celtics  BBall    30.0       SG
# 3                R.J. Hunter          Boston Celtics  BBall    28.0       SG
# 4              Jonas Jerebko          Boston Celtics  BBall     8.0       PF
# 5               Amir Johnson          Boston Celtics  BBall    90.0       PF
# 6              Jordan Mickey          Boston Celtics  BBall    55.0       PF
# 7               Kelly Olynyk          Boston Celtics  BBall    41.0        C
# 8               Terry Rozier          Boston Celtics  BBall    12.0       PG
# 9               Marcus Smart          Boston Celtics  BBall    36.0       PG
# 10           Jared Sullinger          Boston Celtics  BBall     7.0        C
# ...

# %% [markdown]
# ## Broadcasting Operations

# %%
df1['Age'].add(5)
# Out:
# 0      30.0
# 1      30.0
# 2      32.0
# 3      27.0
# 4      34.0
# 5      34.0
# 6      26.0
# 7      30.0
# 8      27.0
# 9      27.0
# 10     29.0
# 11     32.0
# 12     32.0
# 13     25.0
# 14     31.0
# 15     32.0
# 16     29.0
# 17     33.0
# 18     26.0
# 19     37.0
# 20     27.0
# 21     31.0
# 22     28.0
# 23     33.0
# 24     26.0
# 25     31.0
# 26     30.0
# 27     31.0
# 28     33.0
# 29     32.0
#        ...
# 428    30.0
# 429    28.0
# 430    29.0
# 431    32.0
# 432    28.0
# 433    33.0
# 434    39.0
# 435    29.0
# 436    30.0
# 437    29.0
# 438    28.0
# 439    31.0
# 440    35.0
# 441    25.0
# 442    33.0
# 443    28.0
# 444    29.0
# 445    25.0
# 446    29.0
# 447    28.0
# 448    31.0
# 449    28.0
# 450    33.0
# 451    31.0
# 452    25.0
# 453    31.0
# 454    29.0
# 455    31.0
# 456    31.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
df1['Age'] - 5
# Out:
# 0      20.0
# 1      20.0
# 2      22.0
# 3      17.0
# 4      24.0
# 5      24.0
# 6      16.0
# 7      20.0
# 8      17.0
# 9      17.0
# 10     19.0
# 11     22.0
# 12     22.0
# 13     15.0
# 14     21.0
# 15     22.0
# 16     19.0
# 17     23.0
# 18     16.0
# 19     27.0
# 20     17.0
# 21     21.0
# 22     18.0
# 23     23.0
# 24     16.0
# 25     21.0
# 26     20.0
# 27     21.0
# 28     23.0
# 29     22.0
#        ...
# 428    20.0
# 429    18.0
# 430    19.0
# 431    22.0
# 432    18.0
# 433    23.0
# 434    29.0
# 435    19.0
# 436    20.0
# 437    19.0
# 438    18.0
# 439    21.0
# 440    25.0
# 441    15.0
# 442    23.0
# 443    18.0
# 444    19.0
# 445    15.0
# 446    19.0
# 447    18.0
# 448    21.0
# 449    18.0
# 450    23.0
# 451    21.0
# 452    15.0
# 453    21.0
# 454    19.0
# 455    21.0
# 456    21.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
df1["Weight"].mul(0.453592)
# Out:
# 0       81.646560
# 1      106.594120
# 2       92.986360
# 3       83.914520
# 4      104.779752
# 5      108.862080
# 6      106.594120
# 7      107.954896
# 8       86.182480
# 9       99.790240
# 10     117.933920
# 11      83.914520
# 12      99.790240
# 13      97.522280
# 14     114.758776
# 15      97.975872
# 16      86.182480
# 17      90.718400
# 18      99.790240
# 19      90.718400
# 20      94.347136
# 21      99.336648
# 22      79.378600
# 23     124.737800
# 24      90.718400
# 25      99.790240
# 26     107.501304
# 27     112.490816
# 28      92.986360
# 29     100.243832
#           ...
# 428     97.522280
# 429     93.439952
# 430     95.254320
# 431    108.862080
# 432     97.522280
# 433     97.522280
# 434    120.201880
# 435    111.130040
# 436     88.450440
# 437     90.718400
# 438     83.914520
# 439    106.594120
# 440     78.471416
# 441    108.862080
# 442    103.418976
# 443     86.636072
# 444     97.068688
# 445     86.182480
# 446    120.201880
# ...

# %%
df1['Weight in Kilo'] = df1['Weight']* 0.453592
## added the column into the df

# %%
## representy salary in mil
df1['Salary']/1000000
# Out:
# 0       7.730337
# 1       6.796117
# 2            NaN
# 3       1.148640
# 4       5.000000
# 5      12.000000
# 6       1.170960
# 7       2.165160
# 8       1.824360
# 9       3.431040
# 10      2.569260
# 11      6.912869
# 12      3.425510
# 13      1.749840
# 14      2.616975
# 15      3.425510
# 16      0.845059
# 17      1.500000
# 18      1.335480
# 19      6.300000
# 20      1.599840
# 21      0.134215
# 22      1.500000
# 23     19.689000
# 24      1.140240
# 25      0.947276
# 26      0.981348
# 27      0.947276
# 28      0.947276
# 29     11.235955
#          ...
# 428     8.042895
# 429     0.625093
# 430     0.947276
# 431     6.980802
# 432     2.894059
# 433     6.000000
# 434     5.016000
# 435     3.075880
# 436     4.236287
# 437     2.525160
# 438     0.525093
# 439     1.415520
# 440     2.854940
# 441     2.637720
# 442     4.775000
# 443     2.658240
# 444     9.463484
# 445     3.777720
# 446    12.000000
# 447     1.175880
# 448    15.409570
# ...

# %% [markdown]
# ## Value counts methods

# %%
# only works in a series

# %%
df1["Team"].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Dallas Mavericks          15
# Toronto Raptors           15
# Charlotte Hornets         15
# Denver Nuggets            15
# Portland Trail Blazers    15
# Utah Jazz                 15
# Chicago Bulls             15
# Washington Wizards        15
# Philadelphia 76ers        15
# Indiana Pacers            15
# Cleveland Cavaliers       15
# Miami Heat                15
# Phoenix Suns              15
# Sacramento Kings          15
# Boston Celtics            15
# Houston Rockets           15
# Detroit Pistons           15
# Oklahoma City Thunder     15
# Los Angeles Lakers        15
# Brooklyn Nets             15
# Los Angeles Clippers      15
# Atlanta Hawks             15
# Golden State Warriors     15
# San Antonio Spurs         15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %% [markdown]
# ## drop rows with null

# %%
df1.dropna()
## how mthod will remove rows where any value is null, or could set to all null in the row, 
#subset includes only columns to be checked for null, for which the row will be dropped
# Out:
#                         Name                    Team  Sport  Number Position  \
# 0              Avery Bradley          Boston Celtics  BBall     0.0       PG
# 1                Jae Crowder          Boston Celtics  BBall    99.0       SF
# 3                R.J. Hunter          Boston Celtics  BBall    28.0       SG
# 6              Jordan Mickey          Boston Celtics  BBall    55.0       PF
# 7               Kelly Olynyk          Boston Celtics  BBall    41.0        C
# 8               Terry Rozier          Boston Celtics  BBall    12.0       PG
# 9               Marcus Smart          Boston Celtics  BBall    36.0       PG
# 10           Jared Sullinger          Boston Celtics  BBall     7.0        C
# 11             Isaiah Thomas          Boston Celtics  BBall     4.0       PG
# 12               Evan Turner          Boston Celtics  BBall    11.0       SG
# 13               James Young          Boston Celtics  BBall    13.0       SG
# ...

# %% [markdown]
# ## Fill nulls with .fillna() Method

# %%
df1.fillna(0)
#not permanent
# Out:
#                         Name                    Team  Sport  Number Position  \
# 0              Avery Bradley          Boston Celtics  BBall     0.0       PG
# 1                Jae Crowder          Boston Celtics  BBall    99.0       SF
# 2               John Holland          Boston Celtics  BBall    30.0       SG
# 3                R.J. Hunter          Boston Celtics  BBall    28.0       SG
# 4              Jonas Jerebko          Boston Celtics  BBall     8.0       PF
# 5               Amir Johnson          Boston Celtics  BBall    90.0       PF
# 6              Jordan Mickey          Boston Celtics  BBall    55.0       PF
# 7               Kelly Olynyk          Boston Celtics  BBall    41.0        C
# 8               Terry Rozier          Boston Celtics  BBall    12.0       PG
# 9               Marcus Smart          Boston Celtics  BBall    36.0       PG
# 10           Jared Sullinger          Boston Celtics  BBall     7.0        C
# ...

# %%
df1["Salary"].fillna(0, inplace = True)
#directly changes the df

# %%
df1['College'].fillna('No college', inplace = True)

# %% [markdown]
# ## The .astype() Method

# %%
## cannot have any nulls in the df

# %%
nba = pd.read_csv
